# %% [markdown]
# * Google Colab에서 실행시 아나콘다 없이 바로 패키지 설치해서 사용
#
# 1. 아나콘다 설치: https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html#installing-in-silent-mode
#
# 2. 설치 이후 환경 설정
#
# conda config --add channels conda-forge
#
# conda create -n (환경 이름) python=3.7 jupyterlab ipython matplotlib uproot numpy pandas mplhep tqdm
#
# 환경 activate: conda activate (환경 이름)
#
# 환경 deactivate : conda activate (환경 이름)
#
# 추가로 필요한 패키지는 conda install (패키지 이름)을 통해 설치
#
# 3. 환경 activate 이후 jupyter lab통해 .ipynb 파일 실행

# %%
#Google Colab의 경우에는 파일을 업로드해야함
#https://colab.research.google.com/github/StillWork/ds-lab/blob/master/tip_colab_%ED%8C%8C%EC%9D%BC%EC%A0%80%EC%9E%A5%EB%B0%8F%EC%97%85%EB%A1%9C%EB%93%9C_colab.ipynb 참고
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Google Colab에서 사용할시 패키지 설치
# %pip install mplhep
# %pip install uproot
# %pip install tqdm

# %%
#필요한 패키지 import
import mplhep
import numpy as np
import uproot
import math
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
from tqdm import tqdm

#그래프 스타일 설정
plt.style.use(mplhep.style.CMS)  # CMS or ATLAS/LHCb

# %%
#Momentum Reconstruction, Displacement Cut이 적용된 기본 알고리즘
#Displacement cut은 Plane 3/4, Plane 1/2를 통과하는 입자의 Displacement가 특정 범위 이내에만 존재하는 경우
#단위: Position[mm], Momentum[MeV], B-Field[T]
ChunkSize = 1000000

#"" 안에는 데이터 경로 지정, Google Colab의 경우에는 파일을 업로드해야함.
tup = uproot.open("/Users/jaewonl/lab/sitrineo/MC_root/Sr90/Sr90_0.2T_100K_Non_Collimator.cfg.root:ntp1")
nEntries = tup.num_entries

momentum_DCut_True_Sensor1 = []
momentum_DCut_True_Sensor4 = []

momentum_DCut = []

MAG = 0.2

for data in tqdm(tup.iterate(['HitNb', 'HitsensorID', 'HitposINmmX','HitposINmmY', 'HitmomMeVX','HitmomMeVY', 'HitmomMeVZ'], step_size=ChunkSize, library = 'np'), total=int(nEntries / ChunkSize) + 1):    

  for HitNb, sSID, sposX, sposY, smomX, smomY, smomZ in zip(data["HitNb"], data["HitsensorID"], data["HitposINmmX"], data["HitposINmmY"], data["HitmomMeVX"], data["HitmomMeVY"], data["HitmomMeVZ"]):
    #event에 4개의 hit이상이 기록된 경우
    if HitNb>=4:

      angles = []

      plane4 = []
      plane3 = []
      plane2 = []
      plane1 = []

      count4 = 0
      count3 = 0
      count2 = 0
      count1 = 0



      for SID, posX, posY, momX, momY, momZ in zip(sSID, sposX, sposY, smomX, smomY, smomZ):
        #SensorID에 따라 각각의 좌표를 따로 Plane에 저장
          if SID==3:
              count4+=1
              plane4.append((posX, posY, momX, momY, momZ))
          if SID==2:
              count3+=1
              plane3.append((posX, posY, momX, momY, momZ))
          if SID==1:
              count2+=1
              plane2.append((posX, posY, momX, momY, momZ))
          if SID==0:
              count1+=1
              plane1.append((posX, posY, momX, momY, momZ))

      #모든 Plane에 하나의 Hit만이 존재하는 경우
      if (count4==1) and (count3==1) and (count2==1) and (count1==1):
        #[0][0]은 x좌표, [0][1]은 y 좌표에 해당. 예: (plane3[0][0]-plane4[0][0])<2은 plane3/4의 x변위가 2mm 미만이어야한다는 조건
          if ((plane3[0][0]-plane4[0][0])<2) and ((plane3[0][0]-plane4[0][0])>-2) and ((plane3[0][1]-plane4[0][1])>-1.5) and ((plane3[0][1]-plane4[0][1])<2.4) and ((plane1[0][0]-plane2[0][0])<7.5) and ((plane1[0][0]-plane2[0][0])>-7.5):
              #Plane3/4 path, Plane 1/2 path가 이루는 각도를 계산
              angles.append(np.sin(math.atan2(plane3[0][1]-plane4[0][1], -5)) - np.sin(math.atan2(plane1[0][1]-plane2[0][1], -5)))
              momentum_DCut_True_Sensor1.append(math.sqrt(plane1[0][2]**2 + plane1[0][3]**2 + plane1[0][4]**2))
              momentum_DCut_True_Sensor4.append(math.sqrt(plane4[0][2]**2 + plane4[0][3]**2 + plane4[0][4]**2))
          else:    
              pass

      #모든 Plane에 한개 이상의 Hit이 존재하는 경우
      elif count4*count3*count2*count1!=0:
          for crd4 in plane4:
              for crd3 in plane3:
                  for crd2 in plane2:
                      for crd1 in plane1:
                        #경로 조건을 맞추기 위한 조건
                          if ((crd2[0]-crd3[0])<9.5) and ((crd2[0]-crd3[0])>-10) and ((crd2[1]-crd3[1])<3) and ((crd2[1]-crd3[1])>-22):
                              if (((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25))) <= 1:
                                  theta = math.acos(((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25)))
                                  #위와 동일한 Displacement Cut
                                  if ((crd3[0]-crd4[0])<2) and ((crd3[0]-crd4[0])>-2) and ((crd3[1]-crd4[1])>-1.5) and ((crd3[1]-crd4[1])<2.4) and ((crd1[0]-crd2[0])<7.5) and ((crd1[0]-crd2[0])>-7.5):
                                      if theta > 0.3:
                                          angles.append(np.sin(math.atan2(crd3[1]-crd4[1], -5)) - np.sin(math.atan2(crd1[1]-crd2[1], -5)))
                                          momentum_DCut_True_Sensor1.append(math.sqrt(crd1[2]**2 + crd1[3]**2 + crd1[4]**2))
                                          momentum_DCut_True_Sensor4.append(math.sqrt(crd4[2]**2 + crd4[3]**2 + crd4[4]**2))
        

    #저장한 각도로부터 momentum 계산
    for angle in angles:
      momentum_DCut.append(abs(0.3*MAG*20/angle))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.26s/it]

# %%
#Momentum Reconstruction, Radius Cut
#Radius Cut은 이상적인 입자의 궤적을 계산해 각 Plane에서 해당 궤적으로부터 일정 radius 이내에 존재하는 hit만 cut
ChunkSize = 1000000
#tup = uproot.open("/Users/ljw/lab/sitrineo/MC_root/Sr90_0.2T_100K_Collimator3.cfg.root:ntp1")
nEntries = tup.num_entries

momentum_RCut_True_Sensor1 = []
momentum_RCut_True_Sensor4 = []

momentum_RCut = []

#Radius Cut의 경우에는 Momentum 참값이 필요함
origin_Z = 30
origin_Y = 0
origin_X = 0
MOM = 1.61 #1.2878787878787878  #Sample's Original momentum in MeV
MAG = 0.2  #Sample's Magnitude of B-fiqld in T


for data in tqdm(tup.iterate(['HitNb', 'HitsensorID', 'HitposINmmX','HitposINmmY', 'HitmomMeVX','HitmomMeVY', 'HitmomMeVZ'], step_size=ChunkSize, library = 'np'), total=int(nEntries / ChunkSize) + 1):    
    for HitNb, sSID, sposX, sposY, smomX, smomY, smomZ in zip(data["HitNb"], data["HitsensorID"], data["HitposINmmX"], data["HitposINmmY"], data["HitmomMeVX"], data["HitmomMeVY"], data["HitmomMeVZ"]):
        
        if HitNb>=4:
            plane4 = []
            plane3 = []
            plane2 = []
            plane1 = []
            
            count4 = 0
            count3 = 0
            count2 = 0
            count1 = 0
            
            #Radius Cut에 사용될 Radius mm값
            r4 = 5
            r3 = 5
            r2 = 5
            r1 = 5
            
            angles = []
            
            for SID, posX, posY, momX, momY, momZ in zip(sSID, sposX, sposY, smomX, smomY, smomZ):
                if SID==3:
                    count4+=1
                    plane4.append((posX, posY, momX, momY, momZ))
                if SID==2:
                    count3+=1
                    plane3.append((posX, posY, momX, momY, momZ))
                if SID==1:
                    count2+=1
                    plane2.append((posX, posY, momX, momY, momZ))
                if SID==0:
                    count1+=1
                    plane1.append((posX, posY, momX, momY, momZ))
            
            if (count4==1) and (count3==1) and (count2==1) and (count1==1):
                if ((plane3[0][0]-plane4[0][0])<2) and ((plane3[0][0]-plane4[0][0])>-2) and ((plane3[0][1]-plane4[0][1])>-1.5) and ((plane3[0][1]-plane4[0][1])<2.4) and ((plane1[0][0]-plane2[0][0])<7.5) and ((plane1[0][0]-plane2[0][0])>-7.5):
                    
                    #이상적인 궤적을 계산하는 공식
                    try:
                        alpha01 = math.atan2(plane4[0][1]-origin_Y, origin_Z-20)
                        phi01 = math.atan2(plane4[0][0]-origin_X, origin_Z-20)

                        y = math.asin(math.sin(alpha01)-0.3*MAG*0.02/(0.001*MOM))
                        x3 = plane4[0][0] + 5*math.tan(phi01)
                        y3 = plane4[0][1] + 5*math.tan(alpha01)
                        x2 = x3 + (30)*math.tan(phi01)
                        y2 = y3 + (5)*math.tan(alpha01) + (20)*math.tan((alpha01+y)/2) + (5)*math.tan(y)
                        x1 = x2 + (5)*math.tan(phi01)
                        y1 = y2 + (5)*math.tan(y)
                        r4 = math.sqrt(plane4[0][0]**2 + plane4[0][1]**2)
                        r3 = math.sqrt((x3-plane3[0][0])**2 + (y3-plane3[0][1])**2)
                        r2 = math.sqrt((x2-plane2[0][0])**2 + (y2-plane2[0][1])**2)
                        r1 = math.sqrt((x1-plane1[0][0])**2 + (y1-plane1[0][1])**2)
                        
                    except:
                        pass
                    #Radius Cut 적용
                    if (r1<5) and (r2<5) and (r3<5) and (r4<5):
                        angles.append(np.sin(math.atan2(plane3[0][1]-plane4[0][1], -5)) - np.sin(math.atan2(plane1[0][1]-plane2[0][1], -5)))
                        momentum_RCut_True_Sensor1.append(math.sqrt(plane1[0][2]**2 + plane1[0][3]**2 + plane1[0][4]**2))
                        momentum_RCut_True_Sensor4.append(math.sqrt(plane4[0][2]**2 + plane4[0][3]**2 + plane4[0][4]**2))

                else:    
                    pass
            
            
            elif count4*count3*count2*count1!=0:
                for crd4 in plane4:
                    for crd3 in plane3:
                        for crd2 in plane2:
                            for crd1 in plane1:
                                if ((crd2[0]-crd3[0])<9.5) and ((crd2[0]-crd3[0])>-10) and ((crd2[1]-crd3[1])<3) and ((crd2[1]-crd3[1])>-22):
                                    if (((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25))) <= 1:
                                        theta = math.acos(((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25)))
                                        if theta > 0.3:
                                            
                                            try:
                                                alpha01 = math.atan2(crd4[1]-origin_Y, origin_Z-20)
                                                phi01 = math.atan2(crd4[0]-origin_X, origin_Z-20)

                                                y = math.asin(math.sin(alpha01)-0.3*MAG*0.02/(0.001*MOM))
                                                x3 = crd4[0] + 5*math.tan(phi01)
                                                y3 = crd4[1] + 5*math.tan(alpha01)
                                                x2 = x3 + (30)*math.tan(phi01)
                                                y2 = y3 + (5)*math.tan(alpha01) + (20)*math.tan((alpha01+y)/2) + (5)*math.tan(y)
                                                x1 = x2 + (5)*math.tan(phi01)
                                                y1 = y2 + (5)*math.tan(y)
                                                r4 = math.sqrt(crd4[0]**2 + crd4[1]**2)
                                                r3 = math.sqrt((x3-crd3[0])**2 + (y3-crd3[1])**2)
                                                r2 = math.sqrt((x2-crd2[0])**2 + (y2-crd2[1])**2)
                                                r1 = math.sqrt((x1-crd1[0])**2 + (y1-crd1[1])**2)

                                            except:
                                                pass
                                            
                                            if (r1<5) and (r2<5) and (r3<5) and (r4<5):
                                                angles.append(np.sin(math.atan2(crd3[1]-crd4[1], -5)) - np.sin(math.atan2(crd1[1]-crd2[1], -5)))
                                                momentum_RCut_True_Sensor1.append(math.sqrt(crd1[2]**2 + crd1[3]**2 + crd1[4]**2))
                                                momentum_RCut_True_Sensor4.append(math.sqrt(crd4[2]**2 + crd4[3]**2 + crd4[4]**2))
                                        else:
                                            pass
                                else:
                                    pass
            
            else:
                pass
                
            
        else:
            pass
        
        for angle in angles:
            momentum_RCut.append(abs(0.3*MAG*20/angle))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.82s/it]

# %%
#Momentum Reconstruction, Radius Cut + Displacement Cut
ChunkSize = 1000000
#tup = uproot.open("/Users/ljw/lab/sitrineo/MC_root/Sr90_0.2T_100K_Collimator3.cfg.root:ntp1")
nEntries = tup.num_entries

momentum_DRCut_True_Sensor1 = []
momentum_DRCut_True_Sensor4 = []

momentum_DRCut = []

origin_Z = 30
origin_Y = 0
origin_X = 0
MOM = 1.61 #1.2878787878787878  #Sample's Original momentum
MAG = 0.2  #Sample's Magnitude of B-fiqld


for data in tqdm(tup.iterate(['HitNb', 'HitsensorID', 'HitposINmmX','HitposINmmY', 'HitmomMeVX','HitmomMeVY', 'HitmomMeVZ'], step_size=ChunkSize, library = 'np'), total=int(nEntries / ChunkSize) + 1):    
    
    for HitNb, sSID, sposX, sposY, smomX, smomY, smomZ in zip(data["HitNb"], data["HitsensorID"], data["HitposINmmX"], data["HitposINmmY"], data["HitmomMeVX"], data["HitmomMeVY"], data["HitmomMeVZ"]):
        
        if HitNb>=4:
            plane4 = []
            plane3 = []
            plane2 = []
            plane1 = []
            
            count4 = 0
            count3 = 0
            count2 = 0
            count1 = 0
            
            r4 = 5
            r3 = 5
            r2 = 5
            r1 = 5
            
            angles = []
            
            for SID, posX, posY, momX, momY, momZ in zip(sSID, sposX, sposY, smomX, smomY, smomZ):
                if SID==3:
                    count4+=1
                    plane4.append((posX, posY, momX, momY, momZ))
                if SID==2:
                    count3+=1
                    plane3.append((posX, posY, momX, momY, momZ))
                if SID==1:
                    count2+=1
                    plane2.append((posX, posY, momX, momY, momZ))
                if SID==0:
                    count1+=1
                    plane1.append((posX, posY, momX, momY, momZ))
            
            if (count4==1) and (count3==1) and (count2==1) and (count1==1):
                if ((plane3[0][0]-plane4[0][0])<2) and ((plane3[0][0]-plane4[0][0])>-2) and ((plane3[0][1]-plane4[0][1])>-1.5) and ((plane3[0][1]-plane4[0][1])<2.4) and ((plane1[0][0]-plane2[0][0])<7.5) and ((plane1[0][0]-plane2[0][0])>-7.5):
                    
                    try:
                        alpha01 = math.atan2(plane4[0][1]-origin_Y, origin_Z-20)
                        phi01 = math.atan2(plane4[0][0]-origin_X, origin_Z-20)

                        y = math.asin(math.sin(alpha01)-0.3*MAG*0.02/(0.001*MOM))
                        x3 = plane4[0][0] + 5*math.tan(phi01)
                        y3 = plane4[0][1] + 5*math.tan(alpha01)
                        x2 = x3 + (30)*math.tan(phi01)
                        y2 = y3 + (5)*math.tan(alpha01) + (20)*math.tan((alpha01+y)/2) + (5)*math.tan(y)
                        x1 = x2 + (5)*math.tan(phi01)
                        y1 = y2 + (5)*math.tan(y)
                        r4 = math.sqrt(plane4[0][0]**2 + plane4[0][1]**2)
                        r3 = math.sqrt((x3-plane3[0][0])**2 + (y3-plane3[0][1])**2)
                        r2 = math.sqrt((x2-plane2[0][0])**2 + (y2-plane2[0][1])**2)
                        r1 = math.sqrt((x1-plane1[0][0])**2 + (y1-plane1[0][1])**2)
                        
                    except:
                        pass
                    
                    if (r1<5) and (r2<5) and (r3<5) and (r4<5):
                        angles.append(np.sin(math.atan2(plane3[0][1]-plane4[0][1], -5)) - np.sin(math.atan2(plane1[0][1]-plane2[0][1], -5)))
                        momentum_DRCut_True_Sensor1.append(math.sqrt(plane1[0][2]**2 + plane1[0][3]**2 + plane1[0][4]**2))
                        momentum_DRCut_True_Sensor4.append(math.sqrt(plane4[0][2]**2 + plane4[0][3]**2 + plane4[0][4]**2))

                else:    
                    pass
            
            
            elif count4*count3*count2*count1!=0:
                for crd4 in plane4:
                    for crd3 in plane3:
                        for crd2 in plane2:
                            for crd1 in plane1:
                                if ((crd2[0]-crd3[0])<9.5) and ((crd2[0]-crd3[0])>-10) and ((crd2[1]-crd3[1])<3) and ((crd2[1]-crd3[1])>-22):
                                    if (((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25))) <= 1:
                                        theta = math.acos(((crd3[1]-crd4[1])*(crd1[1]-crd2[1])+(-5)*(-5))/(np.sqrt((crd3[1]-crd4[1])**2+25)*np.sqrt((crd1[1]-crd2[1])**2+25)))
                                        if ((crd3[0]-crd4[0])<2) and ((crd3[0]-crd4[0])>-2) and ((crd3[1]-crd4[1])>-1.5) and ((crd3[1]-crd4[1])<2.4) and ((crd1[0]-crd2[0])<7.5) and ((crd1[0]-crd2[0])>-7.5):
                                            if theta > 0.3:

                                                try:
                                                    alpha01 = math.atan2(crd4[1]-origin_Y, origin_Z-20)
                                                    phi01 = math.atan2(crd4[0]-origin_X, origin_Z-20)

                                                    y = math.asin(math.sin(alpha01)-0.3*MAG*0.02/(0.001*MOM))
                                                    x3 = crd4[0] + 5*math.tan(phi01)
                                                    y3 = crd4[1] + 5*math.tan(alpha01)
                                                    x2 = x3 + (30)*math.tan(phi01)
                                                    y2 = y3 + (5)*math.tan(alpha01) + (20)*math.tan((alpha01+y)/2) + (5)*math.tan(y)
                                                    x1 = x2 + (5)*math.tan(phi01)
                                                    y1 = y2 + (5)*math.tan(y)
                                                    r4 = math.sqrt(crd4[0]**2 + crd4[1]**2)
                                                    r3 = math.sqrt((x3-crd3[0])**2 + (y3-crd3[1])**2)
                                                    r2 = math.sqrt((x2-crd2[0])**2 + (y2-crd2[1])**2)
                                                    r1 = math.sqrt((x1-crd1[0])**2 + (y1-crd1[1])**2)

                                                except:
                                                    pass

                                                if (r1<5) and (r2<5) and (r3<5) and (r4<5):
                                                    angles.append(np.sin(math.atan2(crd3[1]-crd4[1], -5)) - np.sin(math.atan2(crd1[1]-crd2[1], -5)))
                                                    momentum_DRCut_True_Sensor1.append(math.sqrt(crd1[2]**2 + crd1[3]**2 + crd1[4]**2))
                                                    momentum_DRCut_True_Sensor4.append(math.sqrt(crd4[2]**2 + crd4[3]**2 + crd4[4]**2))
                                            else:
                                                pass
                                else:
                                    pass
            
            else:
                pass
                
            
        else:
            pass
        
        for angle in angles:
            momentum_DRCut.append(abs(0.3*MAG*20/angle))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 1/1 [00:08<00:00,  8.09s/it]

# %%
#ntuple에 기록된 참값
#Momentum의 경우 SensorID=0을 참값으로 사용해 BTe1_df를 이용
tup = uproot.open("/Users/jaewonl/lab/sitrineo/MC_root/Sr90/Sr90_0.2T_100K_Non_Collimator.cfg.root:ntp1")
BTe_df = tup.arrays(['HitsensorID', 'HitposINmmX','HitposINmmY', 'HitposINmmZ', 'HitmomMeVX','HitmomMeVY', 'HitmomMeVZ'], library='pd')
BTe_df.eval('HitmomMeV = sqrt(HitmomMeVX**2 + HitmomMeVY**2 + HitmomMeVZ**2)', inplace=True)
BTe1_df = BTe_df.query('HitsensorID == 0')
BTe2_df = BTe_df.query('HitsensorID == 1')
BTe3_df = BTe_df.query('HitsensorID == 2')
BTe4_df = BTe_df.query('HitsensorID == 3')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/extras.py:318, in awkward_pandas()
#     317 try:
# --> 318     import awkward_pandas
#     319 except ModuleNotFoundError as err:
#
# ModuleNotFoundError: No module named 'awkward_pandas'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 4
#       1 #ntuple에 기록된 참값
#       2 #Momentum의 경우 SensorID=0을 참값으로 사용해 BTe1_df를 이용
#       3 tup = uproot.open("/Users/jaewonl/lab/sitrineo/MC_root/Sr90/Sr90_0.2T_100K_Non_Collimator.cfg.root:ntp1")
# ----> 4 BTe_df = tup.arrays(['HitsensorID', 'HitposINmmX','HitposINmmY', 'HitposINmmZ', 'HitmomMeVX','HitmomMeVY', 'HitmomMeVZ'], library='pd')
#       5 BTe_df.eval('HitmomMeV = sqrt(HitmomMeVX**2 + HitmomMeVY**2 + HitmomMeVZ**2)', inplace=True)
#       6 BTe1_df = BTe_df.query('HitsensorID == 0')
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:836, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     833                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     835 interp_options = {"ak_add_doc": ak_add_doc}
# --> 836 _ranges_or_baskets_to_arrays(
#     837     self,
#     838     ranges_or_baskets,
#     839     branchid_interpretation,
#     840     entry_start,
#     841     entry_stop,
#     842     decompression_executor,
#     843     interpretation_executor,
#     844     library,
#     845     arrays,
#     846     False,
#     847     interp_options,
#     848 )
#     850 # no longer needed; save memory
#     851 del ranges_or_baskets
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3147, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3144     pass
#    3146 elif isinstance(obj, tuple) and len(obj) == 3:
# -> 3147     uproot.source.futures.delayed_raise(*obj)
#    3149 else:
#    3150     raise AssertionError(obj)
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/source/futures.py:36, in delayed_raise(exception_class, exception_value, traceback)
#      32 def delayed_raise(exception_class, exception_value, traceback):
#      33     """
#      34     Raise an exception from a background thread on the main thread.
#      35     """
# ---> 36     raise exception_value.with_traceback(traceback)
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3116, in _ranges_or_baskets_to_arrays.<locals>.basket_to_array(basket)
#    3113 basket = None
#    3115 if len(basket_arrays) == branchid_num_baskets[branch.cache_key]:
# -> 3116     arrays[branch.cache_key] = interpretation.final_array(
#    3117         basket_arrays,
#    3118         entry_start,
#    3119         entry_stop,
#    3120         branch.entry_offsets,
#    3121         library,
#    3122         branch,
#    3123         interp_options,
#    3124     )
#    3125     # no longer needed, save memory
#    3126     basket_arrays.clear()
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/interpretation/jagged.py:337, in AsJagged.final_array(self, basket_arrays, entry_start, entry_stop, entry_offsets, library, branch, options)
#     325     output = JaggedArray(offsets, content)
#     327     self.hook_before_library_finalize(
#     328         basket_arrays=basket_arrays,
#     329         entry_start=entry_start,
#    (...)
#     334         output=output,
#     335     )
# --> 337 output = library.finalize(
#     338     output, branch, self, entry_start, entry_stop, options
#     339 )
#     341 self.hook_after_final_array(
#     342     basket_arrays=basket_arrays,
#     343     entry_start=entry_start,
#    (...)
#     349     options=options,
#     350 )
#     352 return output
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/interpretation/library.py:844, in Pandas.finalize(self, array, branch, interpretation, entry_start, entry_stop, options)
#     842     return pandas.Series(array, index=index)
#     843 else:
# --> 844     awkward_pandas = uproot.extras.awkward_pandas()
#     845     ak_lib = _libraries[Awkward.name]
#     846     ak_arr = ak_lib.finalize(
#     847         array, branch, interpretation, entry_start, entry_stop, options
#     848     )
#
# File ~/anaconda3/envs/sitrieno/lib/python3.8/site-packages/uproot/extras.py:320, in awkward_pandas()
#     318     import awkward_pandas
#     319 except ModuleNotFoundError as err:
# --> 320     raise ModuleNotFoundError(
#     321         """install the 'awkward-pandas' package with:
#     322 pip install awkward-pandas # not on conda-forge yet"""
#     323     ) from err
#     324 else:
#     325     return awkward_pandas
#
# ModuleNotFoundError: install the 'awkward-pandas' package with:
#     pip install awkward-pandas # not on conda-forge yet

# %%
#이미지의 이름을 label= '(이름)'으로 사용. Latex식 수식 지원.
plt.plot([], [], ' ', label='${}^{90}Sr+{}^{90}Y$ momentum')

#np.histrogram(히스토그램을 그릴 데이터, bin 사이즈)
#np.linspace(시작지점, 끝지점, n등분)
h, bins = np.histogram(momentum_DCut, bins=np.linspace(0, 10,100))

#h, bins는 고정, label은 plot의 이름
mplhep.histplot(h, bins, label='D Cut')

h, bins = np.histogram(momentum_RCut, bins=np.linspace(0, 10,100))
mplhep.histplot(h, bins, label='R cut', histtype='step', color = 'red')

h, bins = np.histogram(momentum_DRCut, bins=np.linspace(0, 10,100))
mplhep.histplot(h, bins, label='D+R cut', histtype='fill', alpha = 0.5, color = 'purple')

#h, bins = np.histogram(BTe1_df['HitmomMeV'], bins=np.linspace(0, 10,100))
#mplhep.histplot(h, bins, label='True', histtype = 'step', alpha = 0.5, color = 'green')

h, bins = np.histogram(momentum_DCut_True_Sensor1, bins=np.linspace(0, 10,100))
mplhep.histplot(h, bins, label='D cut True', histtype='step', alpha = 0.5, color = 'blue')

h, bins = np.histogram(momentum_RCut_True_Sensor1, bins=np.linspace(0, 10,100))
mplhep.histplot(h, bins, label='R cut True', histtype='step', alpha = 0.5, color = 'black')

h, bins = np.histogram(momentum_DRCut_True_Sensor1, bins=np.linspace(0, 10,100))
mplhep.histplot(h, bins, label='D+R cut True', histtype='fill', alpha = 0.5, color = 'cyan')

#plt.plot(bins, momentum_DRCut)

#x,y축 이름 지정
plt.xlabel('Momentum [MeV]')
plt.ylabel('Events')

#y축 log scale. 비활성화는 밑줄을 지우면 됨
plt.yscale('log')

#x축 범위. y축도 동일하게 plt.ylim으로 지정가능
plt.xlim(0,10)
plt.legend()

#이미지를 경로에 저장. 확장자는 .pdf, .png, .jpeg등 가능
#plt.savefig('/Users/ljw/lab/sitrineo/MC_root/figure/Sr90/Sr90_0.2T_100K_Collimator_Sensor_DX10_histogram.png', transparent = True)

#이미지 저장을 비활성화할시 plt.show()를 사용해야함
plt.show()

# %%
#이미지의 이름을 label= '(이름)'으로 사용. Latex식 수식 지원.
plt.plot([], [], ' ', label='${}^{90}Sr+{}^{90}Y$ momentum')

#h, bins = np.histogram(BTe_df['HitmomMeV'], bins=np.linspace(0, 10,500))
#mplhep.histplot(h, bins, label='Total')

#h, bins = np.histogram(BTe1_df['HitmomMeV'], bins=np.linspace(0, 10,500))
#mplhep.histplot(h, bins, label='HitsensorID1=True', color = 'green')

h, bins = np.histogram(momentum_DCut_True_Sensor1, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='D cut True Sensor1', histtype='step', color = 'blue')

h, bins = np.histogram(momentum_RCut_True_Sensor1, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='R cut True Sensor1', histtype='step', color = 'peru')

h, bins = np.histogram(momentum_DRCut_True_Sensor1, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='D+R cut True Sensor1', histtype='step', color = 'cyan')

#h, bins = np.histogram(BTe2_df['HitmomMeV'], bins=np.linspace(0, 10,500))
#mplhep.histplot(h, bins, label='HitsensorID2', color = 'purple')

#h, bins = np.histogram(BTe3_df['HitmomMeV'], bins=np.linspace(0, 10,500))
#mplhep.histplot(h, bins, label='HitsensorID3', color = 'red')

#h, bins = np.histogram(BTe4_df['HitmomMeV'], bins=np.linspace(0, 10,500))
#mplhep.histplot(h, bins, label='HitsensorID4', color = 'blue')

h, bins = np.histogram(momentum_DCut_True_Sensor4, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='D cut True Sensor4', histtype='step', color = 'olive')

h, bins = np.histogram(momentum_RCut_True_Sensor4, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='R cut True Sensor4', histtype='step', color = 'magenta')

h, bins = np.histogram(momentum_DRCut_True_Sensor4, bins=np.linspace(0, 10,500))
mplhep.histplot(h, bins, label='D+R cut True Sensor4', histtype='step', color = 'darkcyan')

#x,y축 이름 지정
plt.xlabel('Momentum [MeV]')
plt.ylabel('Events')

#y축 log scale. 비활성화는 밑줄을 지우면 됨
plt.yscale('log')


#x축 범위. y축도 동일하게 plt.ylim으로 지정가능
plt.xlim(0,3)
plt.legend(loc='upper right', bbox_to_anchor=(1.55, 1.03))

#이미지를 경로에 저장. 확장자는 .pdf, .png, .jpeg등 가능
#plt.savefig('/Users/ljw/lab/sitrineo/MC_root/figure/Sr90/Sr90_0.2T_100K_Collimator_Sensor_DX10.png', transparent = True)

#이미지 저장을 비활성화할시 plt.show()를 사용해야함
plt.show()

# %%
#Grid 정의
fig = plt.figure(figsize=(10,10))
gs = GridSpec(4, 4)

#그림 정의
ax_histogram = fig.add_subplot(gs[0:3, 0:4])
ax_errorbar = fig.add_subplot(gs[3:4,0:4])

ax_histogram.hist(momentum_DRCut, bins = 80, histtype = 'stepfilled', color = 'purple', alpha = 0.7, align = 'mid')
ax_histogram.hist(BTe1_df['HitmomMeV'], bins = 80, histtype = 'stepfilled', color = 'green', alpha = 0.7, align = 'mid')

diff = BTe1_df['HitmomMeV'] - momentum_DRCut

ax_errorbar.hist(diff, bins = 80, histtype = 'stepfilled', color = 'black', alpha = 0.7, align = 'mid')

#x,y축 이름 지정
ax_histogram.set_xlabel('Momentum [MeV]')
ax_histogram.set_ylabel('Events')

#y축 log scale. 비활성화는 밑줄을 지우면 됨
ax_histogram.set_yscale('log')

#x축 범위. y축도 동일하게 plt.ylim으로 지정가능
ax_histogram.set_xlim(0,10)
#plt.legend()

#이미지를 경로에 저장. 확장자는 .pdf, .png, .jpeg등 가능
#plt.savefig('/Users/ljw/lab/sitrineo/MC_root/figure/Sr90_0.2T_100K_Collimator_Test2_histogram.png')

#이미지 저장을 비활성화할시 plt.show()를 사용해야함
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/tz/4rdx0phj76qf3_y19bbpxm9w0000gn/T/ipykernel_61843/1043330968.py in <module>
#      10 ax_histogram.hist(BTe1_df['HitmomMeV'], bins = 80, histtype = 'stepfilled', color = 'green', alpha = 0.7, align = 'mid')
#      11
# ---> 12 diff = BTe1_df['HitmomMeV'] - momentum_DRCut
#      13
#      14 ax_errorbar.hist(diff, bins = 80, histtype = 'stepfilled', color = 'black', alpha = 0.7, align = 'mid')
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/arraylike.py in __sub__(self, other)
#      95     @unpack_zerodim_and_defer("__sub__")
#      96     def __sub__(self, other):
# ---> 97         return self._arith_method(other, operator.sub)
#      98
#      99     @unpack_zerodim_and_defer("__rsub__")
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/series.py in _arith_method(self, other, op)
#    4996         lvalues = extract_array(self, extract_numpy=True)
#    4997         rvalues = extract_array(other, extract_numpy=True)
# -> 4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
#    5000         return self._construct_result(result, name=res_name)
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     140
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#     144         if is_cmp:
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     233         if use_numexpr:
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#     237
#
# ~/opt/anaconda3/envs/sitrineo/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67         _store_test_result(False)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#      71
#
# ValueError: operands could not be broadcast together with shapes (2232,) (5760,)
